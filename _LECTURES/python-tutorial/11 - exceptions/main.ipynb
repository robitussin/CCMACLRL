# %%
num = int(input("What's your fav number?"))
print(num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 tuna = int(input("What's your fav number?"))
#       2 print(tuna)
#
# ValueError: invalid literal for int() with base 10: 'SLY'

# %%
while True:
    try:
        number = int(input("What's your fav number?"))
        print(number)
        break
    except ValueError:
        print("Make sure you enter a number")
# Out:
# Make sure you enter a number
# 5

# %%
while True:
    try:
        firstnumber = int(input("Enter first number?"))
        secondnumber = int(input("Enter second number?"))
        print(firstnumber/secondnumber)
        break
    except ValueError:
        print("Make sure you enter a number")
    except ZeroDivisionError:
        print("Second number should not be zero")
    finally: 
        print("Loop complete")
