# %%
# !pip install beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

# %%
def trade_spider(max_pages):
    page = 0
    while page < max_pages:
        url = 'https://tipidpc.com/viewitem.php?iid=4489046'+ str(page)
        source_code = requests.get(url)
        plain_text = source_code.text
        soup = BeautifulSoup(plain_text)

        for link in soup.find_all('h1', {'class': 'itemname'}):
            h1 = link.getText()
            #print(h1)
            # or print(link.string)
            print(url)
            get_single_item_data(url)
        page += 1

# %%
def get_single_item_data(url):
    source_code = requests.get(url)
    plain_text = source_code.text
    soup = BeautifulSoup(plain_text)

    for item_name in soup.find_all('a'):
        print(item_name.string)

# %%
trade_spider(10)
# Out:
# https://tipidpc.com/viewitem.php?iid=44890460
# None
# Visit the Forums
# Register Now!
# Member Log In
# Advanced Item Search
# Memory for laptop 8Gb ddr4 2400t
# Memory for laptop 4Gb Pc3L 12800S
# 2.5" 1TB HDD WD Blue
# Memory for laptop 4Gb ddr4 3200
# Memory For Desktop , 8gb Ddr4 2666
# Memory For Desktop , 8gb Ddr4 2133
# Memory For Desktop , 4gb Ddr4 2133
# Memory For Desktop , 4gb Ddr4 2133
# Memory For Desktop , 4gb Ddr3 12800
# Memory , 8gb ddr3 desktop Pc12800
# FM2+ Motherboard for A8 7600 w/ back panel
# i3 10th gen
# 8gb 4gb Memory for Desktop DDR4
# Desktop Intel Processor i3 i5 i7 socket 1155 1150 1151
# bumibili ng sirang hard drives
# scrap defective computers for disposal
# asus prime h310m-e r2 0
# Junk or defective computers
# Rx 5700XT
# 6th and 7th gen board
# Items For Sale
# Casing/PSU
# arlex1625
# Site Rules and Guidelines
# Terms of Use
# Lost/Stolen Equipment Registry
# https://tipidpc.com/viewitem.php?iid=44890461
# None
# Visit the Forums
# ...
