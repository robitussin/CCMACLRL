# %%
age = 13

if age < 21:
    print("no beer for you")
# Out:
# no beer for you

# %%
name = "elizer"

if name == "sly":
    print("hello sly")
elif name == "elizer":
    print("hello elizer")
elif name == "ponio":
    print("hello ponio")
# Out:
# hello elizer

# %%
name = "livi"

if name == "sly":
    print("hello sly")
elif name == "elizer":
    print("hello elizer")
elif name == "ponio":
    print("hello ponio")
else:
    print("please register")
# Out:
# please register
