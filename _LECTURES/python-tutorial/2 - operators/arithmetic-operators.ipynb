# %% [markdown]
# Addition

# %%
3 + 4
# Out:
# 7

# %% [markdown]
# Multiplication

# %%
3 * 20
# Out:
# 60

# %% [markdown]
# Operator Precedence

# %%
8 + 2 * 10
# Out:
# 28

# %% [markdown]
# Override Operator Precedence

# %%
(8 + 2) * 10
# Out:
# 100

# %% [markdown]
# Division

# %%
18 / 4
# Out:
# 4.5

# %% [markdown]
# Divison without remainder

# %%
# Drops remainder
18//4
# Out:
# 4

# %% [markdown]
# Modulo Operator

# %%
# Gives remainder
18 % 4
# Out:
# 2

# %%
5 * 5 * 5
# Out:
# 125

# %%
5 ** 3 # Same as 5 * 5 * 5
# Out:
# 125

# %%
tuna = 5

# %%
20 + tuna
# Out:
# 25

# %%
bacon = 18
bacon / tuna
# Out:
# 3.6
