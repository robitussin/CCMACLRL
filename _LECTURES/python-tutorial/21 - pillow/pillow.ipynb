# %%
from PIL import Image

# %%
img = Image.open("pic1.jpeg")
print(img.size)
print(img.format)
# Out:
# (1086, 724)
# JPEG

# %%
img.show()

# %%
# Cropping images
area = (100, 100, 300, 375)
cropped_img = img.crop(area)
cropped_img.show()
