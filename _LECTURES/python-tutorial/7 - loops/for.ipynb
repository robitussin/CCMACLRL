# %%
foods = ['bacon', 'tuna', 'ham', 'sausage', 'beef']

# %%
for f in foods:
    print(f)
    print(len(f))
# Out:
# bacon
# 5
# tuna
# 4
# ham
# 3
# sausage
# 7
# beef
# 4

# %%
for f in foods[:2]:
    print(f)
    print(len(f))
# Out:
# bacon
# 5
# tuna
# 4
