# %% [markdown]
# # Piechart

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('countries.csv')

# %%
y = np.array([18, 17, 4, 39])
mylabels = ["China", "India", "USA", "Others"]

plt.pie(y, labels = mylabels)
plt.show()
