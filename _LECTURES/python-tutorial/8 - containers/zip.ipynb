# %%
first = ['SLY', 'RONA', 'ALPHI']
last = ['PONIO', 'SALAZAR', 'MAGDALUYO']

# %%
names = zip(first, last)

for a, b in names:
    print(a,b)
# Out:
# SLY PONIO
# RONA SALAZAR
# ALPHI MAGDALUYO

# %%
print(names)
